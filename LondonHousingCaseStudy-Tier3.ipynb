# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
from matplotlib import pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.shape
# Out:
# (303, 48)

# %%
properties.head()
# Out:
#            City of London Barking & Dagenham     Barnet     Bexley      Brent  \
# NaT             E09000001          E09000002  E09000003  E09000004  E09000005
# 1995-01-01          91449            50460.2    93284.5    64958.1    71306.6
# 1995-02-01        82202.8            51085.8    93190.2    64787.9    72022.3
# 1995-03-01        79120.7              51269    92247.5    64367.5    72015.8
# 1995-04-01        77101.2            53133.5    90762.9    64277.7    72965.6
#
#               Bromley     Camden    Croydon     Ealing    Enfield    ...      \
# NaT         E09000006  E09000007  E09000008  E09000009  E09000010    ...
# 1995-01-01    81671.5     120933    69158.2    79885.9    72514.7    ...
# 1995-02-01    81657.6     119509    68951.1    80897.1    73155.2    ...
# 1995-03-01    81449.3     120282    68712.4    81379.9    72190.4    ...
# 1995-04-01    81124.4     120098      68610    82188.9    71442.9    ...
#
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties = properties.transpose()

# %%
properties.head()
# Out:
#                           NaT 1995-01-01 1995-02-01 1995-03-01 1995-04-01  \
# City of London      E09000001      91449    82202.8    79120.7    77101.2
# Barking & Dagenham  E09000002    50460.2    51085.8      51269    53133.5
# Barnet              E09000003    93284.5    93190.2    92247.5    90762.9
# Bexley              E09000004    64958.1    64787.9    64367.5    64277.7
# Brent               E09000005    71306.6    72022.3    72015.8    72965.6
#
#                    1995-05-01 1995-06-01 1995-07-01 1995-08-01 1995-09-01  \
# City of London        84409.1    94900.5     110128     112329     104473
# Barking & Dagenham    53042.2    53700.3    52113.1    52232.2    51471.6
# Barnet                  90258    90107.2    91441.2    92361.3    93273.1
# Bexley                63997.1    64252.3    63722.7    64432.6    64509.5
# Brent                   73704    74310.5      74127      73547    73789.5
#
# ...

# %%
properties.index
# Out:
# Index(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley', 'Brent',
#        'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich',
#        'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster',
#        'Unnamed: 33', 'Inner London', 'Outer London', 'Unnamed: 36',
#        'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 46', 'England'],
#       dtype='object')

# %%
properties = properties.reset_index()

# %%
properties.index
# Out:
# RangeIndex(start=0, stop=48, step=1)

# %%
properties.head()
# Out:
#                 index        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0      City of London  E09000001               91449             82202.8
# 1  Barking & Dagenham  E09000002             50460.2             51085.8
# 2              Barnet  E09000003             93284.5             93190.2
# 3              Bexley  E09000004             64958.1             64787.9
# 4               Brent  E09000005             71306.6             72022.3
#
#   1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0             79120.7             77101.2             84409.1
# 1               51269             53133.5             53042.2
# 2             92247.5             90762.9               90258
# 3             64367.5             64277.7             63997.1
# 4             72015.8             72965.6               73704
#
#   1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  \
# 0             94900.5              110128              112329
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties = properties.rename(columns = {'index':'London_Borough', pd.NaT: 'ID'})

# %%
properties.head()
# Out:
#        London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0      City of London  E09000001               91449             82202.8
# 1  Barking & Dagenham  E09000002             50460.2             51085.8
# 2              Barnet  E09000003             93284.5             93190.2
# 3              Bexley  E09000004             64958.1             64787.9
# 4               Brent  E09000005             71306.6             72022.3
#
#   1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0             79120.7             77101.2             84409.1
# 1               51269             53133.5             53042.2
# 2             92247.5             90762.9               90258
# 3             64367.5             64277.7             63997.1
# 4             72015.8             72965.6               73704
#
#   1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  \
# 0             94900.5              110128              112329
# ...

# %%
#determine number of columns
properties.columns
# Out:
# Index([   'London_Borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2019-05-01 00:00:00, 2019-06-01 00:00:00, 2019-07-01 00:00:00,
#        2019-08-01 00:00:00, 2019-09-01 00:00:00, 2019-10-01 00:00:00,
#        2019-11-01 00:00:00, 2019-12-01 00:00:00, 2020-01-01 00:00:00,
#        2020-02-01 00:00:00],
#       dtype='object', length=304)

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
#need fewer columns
properties_values = pd.melt(properties, id_vars= ['London_Borough', 'ID'])

# %%
properties_values.head()
# Out:
#        London_Borough         ID   variable    value
# 0      City of London  E09000001 1995-01-01    91449
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.2
# 2              Barnet  E09000003 1995-01-01  93284.5
# 3              Bexley  E09000004 1995-01-01  64958.1
# 4               Brent  E09000005 1995-01-01  71306.6

# %%
# Re-name the column names
properties_values = properties_values.rename(columns = {'variable': 'Month', 'value': 'Average_price'})

# %%
properties_values.head()
# Out:
#        London_Borough         ID      Month Average_price
# 0      City of London  E09000001 1995-01-01         91449
# 1  Barking & Dagenham  E09000002 1995-01-01       50460.2
# 2              Barnet  E09000003 1995-01-01       93284.5
# 3              Bexley  E09000004 1995-01-01       64958.1
# 4               Brent  E09000005 1995-01-01       71306.6

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
#checking the data types of the properties_values DataFrame
properties_values.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price             object
# dtype: object

# %%
#change the Average_price column to a float numeric type
properties_values['Average_price'] = pd.to_numeric(properties_values['Average_price'])

# %%
#checking the new data types of the properties_values DataFrame
properties_values.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price            float64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
#Checking for equal number of observations in the DataFrame
properties_values.count()
# Out:
# London_Borough    14496
# ID                13590
# Month             14496
# Average_price     13590
# dtype: int64

# %%
#checking the unique values of the 'London_Borough' column
properties_values['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 33',
#        'Inner London', 'Outer London', 'Unnamed: 36', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 46', 'England'], dtype=object)

# %%
#Checking what information is contained in rows where London_Boroughs is 'Unnamed’
properties_values[properties_values['London_Borough'] == 'Unnamed: 33'].head()
# Out:
#     London_Borough   ID      Month  Average_price
# 33     Unnamed: 33  NaN 1995-01-01            NaN
# 81     Unnamed: 33  NaN 1995-02-01            NaN
# 129    Unnamed: 33  NaN 1995-03-01            NaN
# 177    Unnamed: 33  NaN 1995-04-01            NaN
# 225    Unnamed: 33  NaN 1995-05-01            NaN

# %%
#Checking how many rows have NAs as their value for ID
properties_values[properties_values['ID'].isna()]
# Out:
#       London_Borough   ID      Month  Average_price
# 33       Unnamed: 33  NaN 1995-01-01            NaN
# 36       Unnamed: 36  NaN 1995-01-01            NaN
# 46       Unnamed: 46  NaN 1995-01-01            NaN
# 81       Unnamed: 33  NaN 1995-02-01            NaN
# 84       Unnamed: 36  NaN 1995-02-01            NaN
# 94       Unnamed: 46  NaN 1995-02-01            NaN
# 129      Unnamed: 33  NaN 1995-03-01            NaN
# 132      Unnamed: 36  NaN 1995-03-01            NaN
# 142      Unnamed: 46  NaN 1995-03-01            NaN
# 177      Unnamed: 33  NaN 1995-04-01            NaN
# 180      Unnamed: 36  NaN 1995-04-01            NaN
# 190      Unnamed: 46  NaN 1995-04-01            NaN
# 225      Unnamed: 33  NaN 1995-05-01            NaN
# 228      Unnamed: 36  NaN 1995-05-01            NaN
# 238      Unnamed: 46  NaN 1995-05-01            NaN
# 273      Unnamed: 33  NaN 1995-06-01            NaN
# 276      Unnamed: 36  NaN 1995-06-01            NaN
# ...

# %%
# filtering the data with NaN values
NaNFreeDF2 = properties_values.dropna()
NaNFreeDF2.head(48)
# Out:
#           London_Borough         ID      Month  Average_price
# 0         City of London  E09000001 1995-01-01    91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                 Barnet  E09000003 1995-01-01    93284.51832
# 3                 Bexley  E09000004 1995-01-01    64958.09036
# 4                  Brent  E09000005 1995-01-01    71306.56698
# 5                Bromley  E09000006 1995-01-01    81671.47692
# 6                 Camden  E09000007 1995-01-01   120932.88810
# 7                Croydon  E09000008 1995-01-01    69158.16225
# 8                 Ealing  E09000009 1995-01-01    79885.89069
# 9                Enfield  E09000010 1995-01-01    72514.69096
# 10             Greenwich  E09000011 1995-01-01    62300.10169
# 11               Hackney  E09000012 1995-01-01    61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01   124902.86020
# 13              Haringey  E09000014 1995-01-01    76287.56947
# ...

# %%
#Checking for equal number of observations in the DataFrame 
NaNFreeDF2.count()
# Out:
# London_Borough    13590
# ID                13590
# Month             13590
# Average_price     13590
# dtype: int64

# %%
#checking the unique values of the 'London_Borough' column
NaNFreeDF2['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
#Need to drop the rest of the invalid 'London Borough' values
#Here's a list of non-boroughs. 
nonBoroughs = ['Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']

# %%
#Filter the rows whose values for 'London Borough' is not in the nonBoroughs list
NaNFreeDF2[~NaNFreeDF2.London_Borough.isin(nonBoroughs)]
# Out:
#              London_Borough         ID      Month  Average_price
# 0            City of London  E09000001 1995-01-01   9.144898e+04
# 1        Barking & Dagenham  E09000002 1995-01-01   5.046023e+04
# 2                    Barnet  E09000003 1995-01-01   9.328452e+04
# 3                    Bexley  E09000004 1995-01-01   6.495809e+04
# 4                     Brent  E09000005 1995-01-01   7.130657e+04
# 5                   Bromley  E09000006 1995-01-01   8.167148e+04
# 6                    Camden  E09000007 1995-01-01   1.209329e+05
# 7                   Croydon  E09000008 1995-01-01   6.915816e+04
# 8                    Ealing  E09000009 1995-01-01   7.988589e+04
# 9                   Enfield  E09000010 1995-01-01   7.251469e+04
# 10                Greenwich  E09000011 1995-01-01   6.230010e+04
# 11                  Hackney  E09000012 1995-01-01   6.129653e+04
# 12     Hammersmith & Fulham  E09000013 1995-01-01   1.249029e+05
# ...

# %%
#Reassign NaNFreeDF2
NaNFreeDF2 = NaNFreeDF2[~NaNFreeDF2.London_Borough.isin(nonBoroughs)]

# %%
#Create final df DataFrame
df = NaNFreeDF2
df.head()
# Out:
#        London_Borough         ID      Month  Average_price
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698

# %%
df.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price            float64
# dtype: object

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
#Filtering df on the following condition:
#df['London_Borough'] == 'Barnet'
barnet_prices = df[df['London_Borough'] == 'Barnet']
                   
#a line plot of Month against Average Price
#kind ='line', x = 'Month', y='Average_price'
ax = barnet_prices.plot(kind ='line', x = 'Month', y='Average_price')

#Setting that label to the string: 'Price'. 
ax.set_ylabel('Price')
ax.set_title('Barnet Monthly Average Prices')
# Out:
# Text(0.5, 1.0, 'Barnet Monthly Average Prices')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
df['Year'] = df['Month'].apply(lambda t: t.year)

df.head()
# Out:
#        London_Borough         ID      Month  Average_price  Year
# 0      City of London  E09000001 1995-01-01    91448.98487  1995
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660  1995
# 2              Barnet  E09000003 1995-01-01    93284.51832  1995
# 3              Bexley  E09000004 1995-01-01    64958.09036  1995
# 4               Brent  E09000005 1995-01-01    71306.56698  1995

# %%
# Call the tail() method on df
df.tail()
# Out:
#        London_Borough         ID      Month  Average_price  Year
# 14476          Sutton  E09000029 2020-02-01    380197.6513  2020
# 14477   Tower Hamlets  E09000030 2020-02-01    462323.4758  2020
# 14478  Waltham Forest  E09000031 2020-02-01    441113.0235  2020
# 14479      Wandsworth  E09000032 2020-02-01    600088.5899  2020
# 14480     Westminster  E09000033 2020-02-01    975090.9590  2020

# %%
#calculate the mean house price for each year
dfgp = df.groupby(by=['London_Borough', 'Year']).mean()
dfgp.sample(10)
# Out:
#                            Average_price
# London_Borough       Year
# Southwark            1996   70117.306851
# Kingston upon Thames 1998  116399.769158
# Wandsworth           2007  372077.557308
# Kingston upon Thames 1996   87017.757822
# Bexley               2002  136797.964475
# Enfield              2014  294515.793233
# Greenwich            2013  253399.260875
# Havering             2013  226428.817033
# Kingston upon Thames 2000  162805.826108
#                      2009  266774.216575

# %%
#Reset the index for our new DataFrame dfgp
dfgp = dfgp.reset_index()
dfgp.head()
# Out:
#        London_Borough  Year  Average_price
# 0  Barking & Dagenham  1995   51817.969390
# 1  Barking & Dagenham  1996   51718.192690
# 2  Barking & Dagenham  1997   55974.262309
# 3  Barking & Dagenham  1998   60285.821083
# 4  Barking & Dagenham  1999   65320.934441

# %%
#Filtering dfgp on the following condition:
#dfgp['London_Borough'] == 'Barnet'
barnet_prices = dfgp[dfgp['London_Borough'] == 'Barnet']
                   
#a line plot of Year against Average Price
#kind ='line', x = 'Year', y='Average_price'
ax = barnet_prices.plot(kind ='line', x = 'Year', y='Average_price')

#Setting that label to the string: 'Price'. 
ax.set_ylabel('Price')
ax.set_title('Barnet Yearly Average Prices')
# Out:
# Text(0.5, 1.0, 'Barnet Yearly Average Prices')

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
#Create create_price_ratio function:
def create_price_ratio(d):
    y1998 = float(d['Average_price'][d['Year']==1998])
    y2018 = float(d['Average_price'][d['Year']==2018])
    ratio = [y2018/y1998]
    return ratio

# %%
#Test the function
create_price_ratio(dfgp[dfgp['London_Borough']=='Barnet'])
# Out:
# [4.358195917538044]

# %%
# We want to do this for all of the London Boroughs. 
# First, let's make an empty dictionary, called final, where we'll store our ratios for each unique London_Borough.
final = {}

# %%
#Declaring a for loop that will iterate through each of the unique elements of the 'London_Borough' column of our DataFrame dfgp
for b in dfgp['London_Borough'].unique():
    # Let's make our parameter to our create_price_ratio function: i.e., we subset dfgp on 'London_Borough' == b. 
    borough = dfgp[dfgp['London_Borough'] == b]
    # Make a new entry in the final dictionary whose value's the result of calling create_price_ratio with the argument: borough
    final[b] = create_price_ratio(borough)
# We use the function and incorporate that into a new key of the dictionary 
print(final)
# Out:
# {'Barking & Dagenham': [4.89661861291754], 'Barnet': [4.358195917538044], 'Bexley': [4.248977046127877], 'Brent': [4.8945544971392865], 'Bromley': [4.0947846853338765], 'Camden': [4.935353408884261], 'City of London': [5.301620377587609], 'Croydon': [4.201100280024767], 'Ealing': [4.311450902121834], 'Enfield': [4.26347158349581], 'Greenwich': [4.763036347329193], 'Hackney': [6.198285561008662], 'Hammersmith & Fulham': [4.137798101936229], 'Haringey': [5.134624964136042], 'Harrow': [4.0591964329643195], 'Havering': [4.325230371335308], 'Hillingdon': [4.2002730803844575], 'Hounslow': [3.976409106143329], 'Islington': [4.844048012802298], 'Kensington & Chelsea': [5.082465066092464], 'Kingston upon Thames': [4.270549521484271], 'Lambeth': [4.957751163514063], 'Lewisham': [5.449221041059685], 'Merton': [4.741273313294604], 'Newham': [5.305390437201879], 'Redbridge': [4.471182006097364], 'Richmond upon Thames': [4.005161895721457], 'Southwark': [5.516485302379376], 'Sutton': [4.1185226085
# ...

# %%
#Make a variable called df_ratios, and assign it the result of calling the DataFrame method on the dictionary final. 
df_ratios = pd.DataFrame(final)

# %%
#Call the head() method on this variable to check it out. 
df_ratios.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    City of London  Croydon    Ealing   Enfield     ...         Merton  \
# 0         5.30162   4.2011  4.311451  4.263472     ...       4.741273
#
#     Newham  Redbridge  Richmond upon Thames  Southwark    Sutton  \
# 0  5.30539   4.471182              4.005162   5.516485  4.118523
#
#    Tower Hamlets  Waltham Forest  Wandsworth  Westminster
# 0       4.626701        5.834756    4.757709     5.353565
#
# [1 rows x 33 columns]

# %%
# All we need to do now is transpose it, and reset the index! 
df_ratios_T = df_ratios.transpose()
df_ratios = df_ratios_T.reset_index()
df_ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
#Rename the 'index' column as 'London_Borough', and the '0' column to 'Price_Ratios'.
df_ratios.rename(columns={'index':'Borough', 0:'Price_Ratios'}, inplace=True)
df_ratios.head()
# Out:
#               Borough  Price_Ratios
# 0  Barking & Dagenham      4.896619
# 1              Barnet      4.358196
# 2              Bexley      4.248977
# 3               Brent      4.894554
# 4             Bromley      4.094785

# %%
#Sort in descending order and select the top 15 boroughs.
#Make a variable called top15, and assign it the result of calling sort_values() on df_ratios. 
top15 = df_ratios.sort_values(by='Price_Ratios',ascending=False).head(15)
print(top15)
# Out:
#                  Borough  Price_Ratios
# 11               Hackney      6.198286
# 30        Waltham Forest      5.834756
# 27             Southwark      5.516485
# 22              Lewisham      5.449221
# 32           Westminster      5.353565
# 24                Newham      5.305390
# 6         City of London      5.301620
# 13              Haringey      5.134625
# 19  Kensington & Chelsea      5.082465
# 21               Lambeth      4.957751
# 5                 Camden      4.935353
# 0     Barking & Dagenham      4.896619
# 3                  Brent      4.894554
# 18             Islington      4.844048
# 10             Greenwich      4.763036

# %%
#Plot the boroughs that have seen the greatest changes in price.
#Make a variable called ax. Assign it the result of filtering top15 on 'Borough' and 'Price_Ratios', then calling plot(), with
#the parameter kind = 'bar'. 
ax = top15[['Borough','Price_Ratios']].plot(kind='bar')

ax.set_xticklabels(top15.Borough)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(0, 0, 'Waltham Forest'),
#  Text(0, 0, 'Southwark'),
#  Text(0, 0, 'Lewisham'),
#  Text(0, 0, 'Westminster'),
#  Text(0, 0, 'Newham'),
#  Text(0, 0, 'City of London'),
#  Text(0, 0, 'Haringey'),
#  Text(0, 0, 'Kensington & Chelsea'),
#  Text(0, 0, 'Lambeth'),
#  Text(0, 0, 'Camden'),
#  Text(0, 0, 'Barking & Dagenham'),
#  Text(0, 0, 'Brent'),
#  Text(0, 0, 'Islington'),
#  Text(0, 0, 'Greenwich')]

# %%
#Sort in descending order and select the bottom 17 boroughs.
#Make a variable called bottom17, and assign it the result of calling sort_values() on df_ratios. 
bottom17 = df_ratios.sort_values(by='Price_Ratios',ascending=False).tail(17)
print(bottom17)
# Out:
#                  Borough  Price_Ratios
# 23                Merton      4.741273
# 29         Tower Hamlets      4.626701
# 25             Redbridge      4.471182
# 1                 Barnet      4.358196
# 15              Havering      4.325230
# 8                 Ealing      4.311451
# 20  Kingston upon Thames      4.270550
# 9                Enfield      4.263472
# 2                 Bexley      4.248977
# 7                Croydon      4.201100
# 16            Hillingdon      4.200273
# 12  Hammersmith & Fulham      4.137798
# 28                Sutton      4.118523
# 4                Bromley      4.094785
# 14                Harrow      4.059196
# 26  Richmond upon Thames      4.005162
# 17              Hounslow      3.976409

# %% [markdown]
# ### 4. Conclusion
#
# Based on the average price ratios between the years 1998 and 2018, the higher the ratio the greater increase in housing prices for those boroughs during those two decades. All 32 boroughs experienced price increases but about half had a markedly higher increase over the two decades.
#
# The boroughs Hackney, Waltham Forest, Southwark, Lewisham, Westminster, Newham, City of London, Haringey, Kensington & Chelsea, Lambeth, Camden, Barking & Dagenham, Brent, Islington and Greenwich are the top 15 that have the highest average price ratios, and therefore, the greatest housing price increases over the two decades. Hackney is the most expensive, their housing price increased by over six-fold. This indicates that these boroughs are the most desirable to live in.
#
# The boroughs Tower Hamlets, Redbridge, Barnet, Havering, Ealing, Kingston upon Thames, Enfield,  Bexley, Croydon, Hillingdon, Hammersmith & Fulham, Sutton,  Bromley, Harrow, Richmond upon Thames and Hounslow are the bottom 17 that have the lowest average price ratios, and therefore, the lowest housing price increases over the two decades. Hounslow the least expensive, their housing price increased by only just under four-fold. This indicates that these boroughs are the least desirable to live in.
#
# I would like to investigate what indicators made the top 15 boroughs more desirable and the bottom 17 boroughs least desirable, which ultimately influenced the rate of the housing price increases.
